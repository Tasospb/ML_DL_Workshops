# %%
import pandas as pd

f = pd.read_csv(r"C:\Users\tasos\Documents\GitHub\ML_DL_Workshops\Data\all_pokemon.csv")
f
# Out:
#         #         Name      Type  Total   HP  Attack  Defense  Sp. Atk  \
# 0       1    Bulbasaur     Grass    318   45      49       49       65
# 1       1    Bulbasaur    Poison    318   45      49       49       65
# 2       2      Ivysaur     Grass    405   60      62       63       80
# 3       2      Ivysaur    Poison    405   60      62       63       80
# 4       3     Venusaur     Grass    525   80      82       83      100
# ...   ...          ...       ...    ...  ...     ...      ...      ...
# 1415  806  Blacephalon      Fire    570   53     127       53      151
# 1416  806  Blacephalon     Ghost    570   53     127       53      151
# 1417  807      Zeraora  Electric    600   88     112       75      102
# 1418  808       Meltan     Steel    300   46      65       65       55
# 1419  809     Melmetal     Steel    600  135     143      143       80
#
#       Sp. Def  Speed
# 0          65     45
# 1          65     45
# 2          80     60
# 3          80     60
# ...

# %%
f.max()

#ZygardeComplete Forme is the strongest pokemon and its water type
# Out:
# #                            809
# Name       ZygardeComplete Forme
# Type                       Water
# Total                        780
# HP                           255
# Attack                       190
# Defense                      230
# Sp. Atk                      194
# Sp. Def                      230
# Speed                        180
# dtype: object

# %%
d = f.loc[:,["Total","HP","Attack"]]
d.median()
# Out:
# Total     464.0
# HP         68.0
# Attack     78.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Calculate means and variances
means = d.mean()
variances = d.var()

# Create bar chart
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plot means
means.plot(kind='bar', ax=ax1, color='skyblue')
ax1.set_title('Average Values')
ax1.set_ylabel('Value')
ax1.grid(True, alpha=0.3)

# Plot variances
variances.plot(kind='bar', ax=ax2, color='lightgreen')
ax2.set_title('Variances')
ax2.set_ylabel('Value')
ax2.grid(True, alpha=0.3)

# Adjust layout to prevent overlap
plt.tight_layout()

# Add value labels on top of each bar
for ax in [ax1, ax2]:
    for i, v in enumerate(ax.containers[0]):
        ax.text(v.get_x() + v.get_width()/2, 
                v.get_height(), 
                f'{v.get_height():.2f}', 
                ha='center', 
                va='bottom')

plt.show()

# Print numerical values
print("\nMean values:")
print(means)
print("\nVariances:")
print(variances)
# Out:
# Mean values:
# Total     445.802113
# HP         70.176056
# Attack     81.567606
# dtype: float64
#
# Variances:
# Total     14526.891750
# HP          656.139525
# Attack     1082.489436
# dtype: float64
