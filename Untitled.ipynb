# %%
import random


#this is used for the user to choose between the different options for the game 
def get_player_choice(player_num=""):
    while True:
        choice = input(f"Player{player_num}, Please select one choice from the following (rock|paper|scissors): ").lower()
        if choise in ['rock','paper','scissors']:
            return choice
        print(f"Invalid. You have to choose from one of the following rock|paper|scissors")

#this is used to randomly generate a choice
def get_computer_choice():
    return random.choice(['rock', 'paper','scissors'])

#rules of the game

#if both the player's choise and computer's choice are the same it's a tie

def determine_winner(choice1, choice2):
    if choice1 == choice2:
        return "Tie"

    winning_rules = {
        'rock' : 'scissors',
        'scissors' : 'paper',
        'paper' : 'rock'  } 

    if winning_rules[choice1] == choice2:
        return "Player 1"
    return "Player 2"
    

def game():
    print("Welcome to the game of Paper Scissors Rock")
    print("Would you like to play again the computer or a player")
    game_mode: input("If you would like to play again the computer press 1 or if you would like to play again a player input 2")

    while True:
        if game_mode == "1":
            player_choice = get_player_choice()
            computer_choice = get_computer_choice()

            print(f"You chose: {player_choice}")
            print(f"Computer chose: {computer_choice}")

            winner = determine_winner(player_choice,computer_choice)
            if winner == "Tie":
                print("The game is a tie")
            elif winner == "Player":
                print("The winner is the Player")
            else:
                print("The winner is the Computer")

        else:
            player1_choice = get_player_choice("1")
            player2_choice = get_player_choice("2")

            print(f"\nPlayer 1 chose: {player1_choice}")
            print(f"Player 2 chose: {player2_choice}")

            winner = determine_winner(player1_choice,player2_choise)
            if winner == "Tie":
                print("The game is a tie")
            else:
                print(f"The winner is {winner}")
        
                play_again = input("\nPlay again? (yes/no): ").lower()
        if play_again != 'yes':
            break

   
        game()
